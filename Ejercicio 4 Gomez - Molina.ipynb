# %% [markdown]
# <div style="text-align: center;">
#
# ## Escuela Politécnica Nacional
#
# </div>
#
# **Integrantes:**
#
#  Kevin Gómez
#
#  Dany Molina Israel
#
# <div style="text-align: center;">
#
# ## Taller 1- Ejericio 4
#
# </div>

# %%
# Importamos las librerías 
import numpy as np
import matplotlib.pyplot as plt

# Serie Geométrica 
r = 0.5  # razón de la serie
n_terminos = 30  # cantidad de términos
suma_geom = []  # lista para guardar las sumas parciales
suma_actual = 0

for n in range(n_terminos):
    termino = r ** n
    suma_actual += termino
    suma_geom.append(suma_actual)

# Serie Armónica 
n_armonica = 1000  # cantidad de términos
suma_arm = []  # lista para guardar las sumas parciales
suma_actual_arm = 0

for n in range(1, n_armonica + 1):
    termino = 1 / n
    suma_actual_arm += termino
    suma_arm.append(suma_actual_arm)

# Graficar las dos series 
plt.figure(figsize=(14, 6))  # tamaño de la figura

# Subgráfico 1: Serie Geométrica
plt.subplot(1, 2, 1)
plt.plot(range(1, n_terminos + 1), suma_geom, marker='o')
plt.axhline(y=1/(1 - r), color='red', linestyle='--', label=f'Límite Teórico = {1/(1 - r):.2f}')
plt.title("Convergencia de la Serie Geométrica")
plt.xlabel("Número de términos")
plt.ylabel("Suma parcial")
plt.legend()
plt.grid(True)

# Subgráfico 2: Serie Armónica
plt.subplot(1, 2, 2)
plt.plot(range(1, n_armonica + 1), suma_arm, color='green')
plt.title("Crecimiento de la Serie Armónica")
plt.xlabel("Número de términos")
plt.ylabel("Suma parcial")
plt.grid(True)

# Mostrar ambos gráficos
plt.tight_layout()
plt.show()
